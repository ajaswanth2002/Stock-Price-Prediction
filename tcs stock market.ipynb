# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
df=pd.read_csv('INFY.NS.csv.xls')
pd.set_option('display.max_rows', df.shape[0]+1)
print(df)
# Out:
#            Date         Open         High          Low        Close  \
# 0    2018-04-02   570.500000   574.775024   560.650024   568.575012
# 1    2018-04-03   567.349976   571.775024   564.049988   570.224976
# 2    2018-04-04   572.000000   572.275024   560.000000   562.099976
# 3    2018-04-05   569.775024   575.650024   564.549988   573.775024
# 4    2018-04-06   571.500000   573.000000   561.049988   563.500000
# 5    2018-04-09   562.500000   562.900024   553.275024   555.625000
# 6    2018-04-10   556.000000   562.250000   552.700012   556.700012
# 7    2018-04-11   559.000000   565.750000   558.250000   562.125000
# 8    2018-04-12   564.724976   586.375000   562.500000   581.299988
# 9    2018-04-13   587.000000   592.950012   575.125000   585.724976
# 10   2018-04-16   551.000000   570.000000   551.000000   566.599976
# 11   2018-04-17   563.500000   563.700012   557.500000   562.599976
# 12   2018-04-18   561.424988   567.375000   556.924988   562.974976
# ...

# %%
df.set_index("Date", drop=False,inplace=True)
print(df)
# Out:
#                   Date         Open         High          Low        Close  \
# Date
# 2018-04-02  2018-04-02   570.500000   574.775024   560.650024   568.575012
# 2018-04-03  2018-04-03   567.349976   571.775024   564.049988   570.224976
# 2018-04-04  2018-04-04   572.000000   572.275024   560.000000   562.099976
# 2018-04-05  2018-04-05   569.775024   575.650024   564.549988   573.775024
# 2018-04-06  2018-04-06   571.500000   573.000000   561.049988   563.500000
# 2018-04-09  2018-04-09   562.500000   562.900024   553.275024   555.625000
# 2018-04-10  2018-04-10   556.000000   562.250000   552.700012   556.700012
# 2018-04-11  2018-04-11   559.000000   565.750000   558.250000   562.125000
# 2018-04-12  2018-04-12   564.724976   586.375000   562.500000   581.299988
# 2018-04-13  2018-04-13   587.000000   592.950012   575.125000   585.724976
# 2018-04-16  2018-04-16   551.000000   570.000000   551.000000   566.599976
# ...

# %%
df.Close.plot(figsize=(14,7))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
data=df[['Date','Open','High','Low','Volume']]
print(data)
# Out:
#                   Date         Open         High          Low    Volume
# Date
# 2018-04-02  2018-04-02   570.500000   574.775024   560.650024   8072702
# 2018-04-03  2018-04-03   567.349976   571.775024   564.049988   4077168
# 2018-04-04  2018-04-04   572.000000   572.275024   560.000000   4813302
# 2018-04-05  2018-04-05   569.775024   575.650024   564.549988   7763544
# 2018-04-06  2018-04-06   571.500000   573.000000   561.049988   5937742
# 2018-04-09  2018-04-09   562.500000   562.900024   553.275024   7202882
# 2018-04-10  2018-04-10   556.000000   562.250000   552.700012   8926058
# 2018-04-11  2018-04-11   559.000000   565.750000   558.250000   9025574
# 2018-04-12  2018-04-12   564.724976   586.375000   562.500000  17044366
# 2018-04-13  2018-04-13   587.000000   592.950012   575.125000  21227038
# 2018-04-16  2018-04-16   551.000000   570.000000   551.000000  24745084
# 2018-04-17  2018-04-17   563.500000   563.700012   557.500000  10397940
# ...

# %%
df.reset_index(drop=True, inplace=True)
print(df)
# Out:
#            Date         Open         High          Low        Close  \
# 0    2018-04-02   570.500000   574.775024   560.650024   568.575012
# 1    2018-04-03   567.349976   571.775024   564.049988   570.224976
# 2    2018-04-04   572.000000   572.275024   560.000000   562.099976
# 3    2018-04-05   569.775024   575.650024   564.549988   573.775024
# 4    2018-04-06   571.500000   573.000000   561.049988   563.500000
# 5    2018-04-09   562.500000   562.900024   553.275024   555.625000
# 6    2018-04-10   556.000000   562.250000   552.700012   556.700012
# 7    2018-04-11   559.000000   565.750000   558.250000   562.125000
# 8    2018-04-12   564.724976   586.375000   562.500000   581.299988
# 9    2018-04-13   587.000000   592.950012   575.125000   585.724976
# 10   2018-04-16   551.000000   570.000000   551.000000   566.599976
# 11   2018-04-17   563.500000   563.700012   557.500000   562.599976
# 12   2018-04-18   561.424988   567.375000   556.924988   562.974976
# ...

# %%
lag_features='Close'
window1=200

df_rolling_200d = df[lag_features].rolling(window=window1, min_periods=1)
df_mean_200d = df_rolling_200d.mean().shift(0).reset_index().astype(np.float32)

df["Close_mean_200d"]=df_mean_200d[lag_features].astype('float32')
  
mov_200d=df["Close_mean_200d"]
print(mov_200d)
# Out:
# 0       568.575012
# 1       569.400024
# 2       566.966675
# 3       568.668762
# 4       567.635010
# 5       565.633362
# 6       564.357117
# 7       564.078125
# 8       565.991638
# 9       567.965027
# 10      567.840881
# 11      567.404175
# 12      567.063477
# 13      567.017822
# 14      568.498352
# 15      570.082825
# 16      570.504395
# 17      571.041687
# 18      571.946045
# 19      572.978760
# 20      574.253540
# 21      575.356812
# 22      576.048889
# 23      576.486450
# 24      577.086975
# 25      577.305786
# 26      577.603699
# 27      577.832153
# 28      578.264648
# 29      578.810852
# 30      579.406433
# 31      579.892944
# 32      580.243164
# 33      580.577209
# 34      580.839294
# 35      581.286133
# 36      581.587830
# 37      582.348694
# 38      583.164124
# 39      583.765015
# 40      584.364624
# 41      584.876160
# 42      585.597656
# 43      586.161377
# 44      586.906677
# 45      587.417908
# 46      588.084045
# ...

# %%
FullData=df[['Close','Close_mean_200d']].values
print(FullData[14:22])
 
# Feature Scaling for fast training of neural networks
from sklearn.preprocessing import StandardScaler, MinMaxScaler
 
# Choosing between Standardization or normalization
#sc = StandardScaler()
sc=MinMaxScaler()
 
DataScaler = sc.fit(FullData)
X=DataScaler.transform(FullData)
#X=FullData
 
print('### After Normalization ###')
X[14:22]
# Out:
# [[589.224976   568.49835205]
#  [593.849976   570.08282471]
#  [577.25       570.50439453]
#  [580.174988   571.04168701]
#  [588.224976   571.94604492]
#  [592.599976   572.97875977]
#  [599.75       574.25354004]
#  [598.525024   575.35681152]]
# ### After Normalization ###
# array([[0.04442515, 0.00383519],
#        [0.04769822, 0.00520995],
#        [0.0359506 , 0.00557572],
#        [0.03802058, 0.0060419 ],
#        [0.04371747, 0.00682656],
#        [0.04681361, 0.00772259],
#        [0.0518736 , 0.00882865],
#        [0.0510067 , 0.0097859 ]])

# %%
# split into samples
X_samples = list()
y_samples = list()
 
NumerOfRows = len(X)
TimeSteps=10  # next day's Price Prediction is based on last how many past day's prices
 
# Iterate thru the values to create combinations
for i in range(TimeSteps , NumerOfRows , 1):
    x_sample = X[i-TimeSteps:i]
    y_sample = X[i]
    X_samples.append(x_sample)
    y_samples.append(y_sample)
 
################################################
# Reshape the Input as a 3D (number of samples, Time Steps, Features)
X_data=np.array(X_samples)
X_data=X_data.reshape(X_data.shape[0],X_data.shape[1], 2)
print('\n#### Input Data shape ####')
print(X_data.shape)
 
# We do not reshape y as a 3D data  as it is supposed to be a single column only
y_data=np.array(y_samples)
print('\n#### Output Data shape ####')
print(y_data.shape)
# Out:
# #### Input Data shape ####
# (977, 10, 2)
#
# #### Output Data shape ####
# (977, 2)

# %%
# Choosing the number of testing data records
TestingRecords=5

# Splitting the data into train and test
X_train=X_data[:-TestingRecords]
X_test=X_data[-TestingRecords:]
y_train=y_data[:-TestingRecords]
y_test=y_data[-TestingRecords:]


############################################

# Printing the shape of training and testing
print('\n#### Training Data shape ####')
print(X_train.shape)
print(y_train.shape)
print('\n#### Testing Data shape ####')
print(X_test.shape)
print(y_test.shape)
# Out:
# #### Training Data shape ####
# (972, 10, 2)
# (972, 2)
#
# #### Testing Data shape ####
# (5, 10, 2)
# (5, 2)

# %%
# Visualizing the input and output being sent to the LSTM model
for inp, out in zip(X_train[0:2], y_train[0:2]):
    print(inp,'--', out)
# Out:
# [[0.0298114  0.0039017 ]
#  [0.03097906 0.00461752]
#  [0.02522909 0.00250624]
#  [0.03349139 0.00398304]
#  [0.02621987 0.00308611]
#  [0.02064682 0.00134939]
#  [0.02140759 0.00024207]
#  [0.0252468  0.        ]
#  [0.03881673 0.00166025]
#  [0.04194824 0.00337245]] -- [0.02841369 0.00326474]
# [[0.03097906 0.00461752]
#  [0.02522909 0.00250624]
#  [0.03349139 0.00398304]
#  [0.02621987 0.00308611]
#  [0.02064682 0.00134939]
#  [0.02140759 0.00024207]
#  [0.0252468  0.        ]
#  [0.03881673 0.00166025]
#  [0.04194824 0.00337245]
#  [0.02841369 0.00326474]] -- [0.02558293 0.00288583]

# %%
# Defining Input shapes for LSTM
TimeSteps=X_train.shape[1]
TotalFeatures=X_train.shape[2]
print("Number of TimeSteps:", TimeSteps)
print("Number of Features:", TotalFeatures)
# Out:
# Number of TimeSteps: 10
# Number of Features: 2

# %%
# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# Initialising the RNN
regressor = Sequential()

# Adding the First input hidden layer and the LSTM layer
# return_sequences = True, means the output of every time step to be shared with hidden next layer
regressor.add(LSTM(units = 6, activation = 'relu', input_shape = (TimeSteps, TotalFeatures), return_sequences=True))

# Adding the Second Second hidden layer and the LSTM layer
regressor.add(LSTM(units = 6, activation = 'relu', input_shape = (TimeSteps, TotalFeatures), return_sequences=True))

# Adding the Second Third hidden layer and the LSTM layer
regressor.add(LSTM(units = 6, activation = 'relu', return_sequences=False ))


# Adding the output layer
regressor.add(Dense(units = 2))

# Compiling the RNN
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

##################################################

import time
# Measuring the time taken by the model to train
StartTime=time.time()
# Fitting the RNN to the Training set
regressor.fit(X_train, y_train, batch_size = 5, epochs = 100)

EndTime=time.time()
print("## Total Time Taken: ", round((EndTime-StartTime)/60), 'Minutes ##')
# Out:
# Epoch 1/100
# 195/195 [==============================] - 20s 17ms/step - loss: 0.0398
# Epoch 2/100
# 195/195 [==============================] - 4s 19ms/step - loss: 0.0030
# Epoch 3/100
# 195/195 [==============================] - 4s 19ms/step - loss: 0.0016
# Epoch 4/100
# 195/195 [==============================] - 3s 17ms/step - loss: 0.0013
# Epoch 5/100
# 195/195 [==============================] - 3s 17ms/step - loss: 9.8135e-04
# Epoch 6/100
# 195/195 [==============================] - 3s 17ms/step - loss: 7.2877e-04
# Epoch 7/100
# 195/195 [==============================] - 3s 17ms/step - loss: 6.4328e-04
# Epoch 8/100
# 195/195 [==============================] - 3s 17ms/step - loss: 5.5007e-04
# Epoch 9/100
# 195/195 [==============================] - 3s 17ms/step - loss: 5.4926e-04
# Epoch 10/100
# 195/195 [==============================] - 3s 17ms/step - loss: 5.2033e-04
# Epoch 11/100
# 195/195 [==============================] - 3s 17ms/step - loss: 5.0634e-04
# ...

# %%
# Making predictions on test data
predicted_Price = regressor.predict(X_test)
Testpredictions = DataScaler.inverse_transform(predicted_Price)
Trainpredictions=DataScaler.inverse_transform(regressor.predict(X_train))
print(Testpredictions.shape)
print(Testpredictions)
print(Trainpredictions)

print('#### Predicted Prices ####')


# Getting the original price values for testing data
orig=y_test
orig=DataScaler.inverse_transform(y_test)
print('\n#### Original Prices ####')
print(orig)
# Out:
# ...
# 31/31 [==============================] - 0s 7ms/step
# (5, 2)
# [[1855.8859 1696.0854]
#  [1858.9597 1697.6533]
#  [1861.8809 1699.1243]
#  [1861.3124 1701.6436]
#  [1858.102  1704.5968]]
# [[ 574.30206  570.9792 ]
#  [ 575.434    570.7805 ]
#  [ 573.3616   570.22754]
#  ...
#  [1859.8618  1699.6036 ]
#  [1856.4346  1696.9581 ]
#  [1847.0178  1694.8811 ]]
# #### Predicted Prices ####
#
# #### Original Prices ####
# [[1872.400024   1707.02478027]
#  [1886.699951   1709.5300293 ]
#  [1876.550049   1711.96447754]
#  [1873.900024   1714.26928711]
#  [1886.         1716.62280273]]

# %%
# Making predictions on test data
predicted_Price = regressor.predict(X_test)
predicted_Price = DataScaler.inverse_transform(predicted_Price)
print(predicted_Price.shape)
print("predicted prices:")
for i in range(5):
    print(predicted_Price[i][0])

# Getting the original price values for testing data
orig=y_test
orig=DataScaler.inverse_transform(y_test)
print("original prices:")
for i in range(5):
    print(orig[i][0])

# Accuracy of the predictions
print('Accuracy:', 100 - (100*(abs(orig-predicted_Price)/orig)).mean())

predicted_Price.shape
# Out:
# 1/1 [==============================] - 0s 51ms/step
# (5, 2)
# predicted prices:
# 1855.8859
# 1858.9597
# 1861.8809
# 1861.3124
# 1858.102
# original prices:
# 1872.400024
# 1886.6999510000003
# 1876.5500489999997
# 1873.900024
# 1886.0
# Accuracy: 99.11923841238702
# (5, 2)

# %%
# Last 10 days prices
Last10Days=np.array([[3655.899902,3672.750000,3626.699951,3700.949951,3712.399902,3749.850098,3707.449951,3707.699951 ,3705.350098,3731.550049],
                   [3565.622803,3568.1906,3570.559,3573.416748,3576.272461,3579.302979,3581.924316,3584.461914,3586.987549,3589.561279]])

print(Last10Days.shape)
p=Last10Days.transpose()
 
# Normalizing the data just like we did for training the model
Last10Days=DataScaler.transform(p)
print(Last10Days)
 
# Changing the shape of the data to 3D
# Choosing TimeSteps as 10 because we have used the same for training
NumSamples=1
TimeSteps=10
NumFeatures=2
Last10Days=Last10Days.reshape(NumSamples,TimeSteps,NumFeatures)
 
#############################
 
# Making predictions on data
predicted_Price = regressor.predict(Last10Days)
predicted_Price = DataScaler.inverse_transform(predicted_Price)
predicted_Price
# Out:
# (2, 10)
# [[2.21467741 2.6042762 ]
#  [2.22660204 2.60650414]
#  [2.19401293 2.60855907]
#  [2.24655884 2.61103858]
#  [2.25466184 2.61351633]
#  [2.28116494 2.61614574]
#  [2.25115882 2.61842014]
#  [2.25133574 2.62062187]
#  [2.24967277 2.62281323]
#  [2.26821419 2.62504631]]
# 1/1 [==============================] - 0s 36ms/step
# array([[1660.2732, 1861.8124]], dtype=float32)

# %%
print("predicted close price is:",predicted_Price[0][0])
# Out:
# predicted close price is: 1660.2732

# %%
Trainpredictions=Trainpredictions[ :,0]
Testpredictions=Testpredictions[ :,0]
FullPredData=np.append(Trainpredictions,Testpredictions)
dfU=pd.to_datetime(df["Date"][10:])
dates_to_display = ['2018-04-02','2018-08-02','2018-12-02','2019-04-02','2019-08-02','2019-12-02','2020-04-02', '2020-08-02','2020-12-02','2021-04-02','2021-08-02','2021-12-02','2022-03-24']
dates_to_display = pd.to_datetime(dates_to_display)
plt.plot(dfU, df['Close'][10:],color='blue',label='original_price')
plt.plot(dfU,FullPredData,color='red',label='Predicted_price')
plt.ylabel('Close_price')
plt.title('Tcs')
plt.legend(loc='upper right')
fig=plt.gcf()
fig.set_figwidth(20)
fig.set_figheight(8)
plt.xticks(dates_to_display, rotation=45)  # set the x-axis ticks to the specified dates and rotate the labels by 45 degrees
plt.show()
